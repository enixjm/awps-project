# %%
import os

import boto3
import pandas as pd
import json

# %%
s3 = boto3.resource('s3')
bucket_name = 'processedprogrammers'

bucket = s3.Bucket(bucket_name)

# %%
prefix = './'
for object in bucket.objects.filter():
    if object.key == prefix:
        os.makedirs(os.path.dirname(object.key), exist_ok=True)
        continue;
    bucket.download_file(object.key, object.key)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/b5/jx16xxp14z92_scmr6jgz3br0000gn/T/ipykernel_25246/1106639076.py in <module>
#       4         os.makedirs(os.path.dirname(object.key), exist_ok=True)
#       5         continue;
# ----> 6     bucket.download_file(object.key, object.key)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/boto3/s3/inject.py in bucket_download_file(self, Key, Filename, ExtraArgs, Callback, Config)
#     275         transfer.
#     276     """
# --> 277     return self.meta.client.download_file(
#     278         Bucket=self.name,
#     279         Key=Key,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/boto3/s3/inject.py in download_file(self, Bucket, Key, Filename, ExtraArgs, Callback, Config)
#     188     """
#     189     with S3Transfer(self, Config) as transfer:
# --> 190         return transfer.download_file(
#     191             bucket=Bucket,
#     192             key=Key,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/boto3/s3/transfer.py in download_file(self, bucket, key, filename, extra_args, callback)
#     318         )
#     319         try:
# --> 320             future.result()
#     321         # This is for backwards compatibility where when retries are
#     322         # exceeded we need to throw the same error from boto3 instead of
#
# ~/opt/anaconda3/lib/python3.9/site-packages/s3transfer/futures.py in result(self)
#     104         except KeyboardInterrupt as e:
#     105             self.cancel()
# --> 106             raise e
#     107
#     108     def cancel(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/s3transfer/futures.py in result(self)
#     101             # however if a KeyboardInterrupt is raised we want want to exit
#     102             # out of this and propagate the exception.
# --> 103             return self._coordinator.result()
#     104         except KeyboardInterrupt as e:
#     105             self.cancel()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/s3transfer/futures.py in result(self)
#     259         # possible value integer value, which is on the scale of billions of
#     260         # years...
# --> 261         self._done_event.wait(MAXINT)
#     262
#     263         # Once done waiting, raise an exception if present or return the
#
# ~/opt/anaconda3/lib/python3.9/threading.py in wait(self, timeout)
#     572             signaled = self._flag
#     573             if not signaled:
# --> 574                 signaled = self._cond.wait(timeout)
#     575             return signaled
#     576
#
# ~/opt/anaconda3/lib/python3.9/threading.py in wait(self, timeout)
#     310         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#     314             else:
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame()

for obj in bucket.objects.all():
    json_string = obj.get()['Body'].read().decode('utf-8')
    json_dict = json.loads(json_string)
    df = df.append(json_dict, ignore_index=True)
# Out:
#         id CompanyName           Pay   Career  \
# 0  10581.0     비바이노베이션  [4000, 6000]  [6, 15]
#
#                                 Stacks          Job  \
# 0  [Django, React Native, Swift, Java]  [시스템 소프트웨어]
#
#                                             MainData                 시간
# 0  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:26
#         id CompanyName           Pay   Career  \
# 0  10581.0     비바이노베이션  [4000, 6000]  [6, 15]
# 1  10651.0        페이히어  [2400, 8000]   [4, 8]
#
#                                 Stacks                    Job  \
# 0  [Django, React Native, Swift, Java]            [시스템 소프트웨어]
# 1  [JavaScript, React Native, ReactJS]  [프론트엔드,  안드로이드,  iOS]
#
#                                             MainData                 시간
# 0  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:26
# 1  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:47
#         id   CompanyName           Pay   Career  \
# 0  10581.0       비바이노베이션  [4000, 6000]  [6, 15]
# 1  10651.0          페이히어  [2400, 8000]   [4, 8]
# 2  10681.0  버킷플레이스(오늘의집)  [3000, 6000]   [2, 5]
#
#                                 Stacks                    Job  \
# 0  [Django, React Native, Swift, Java]            [시스템 소프트웨어]
# 1  [JavaScript, React Native, ReactJS]  [프론트엔드,  안드로이드,  iOS]
# 2          [Shell, JavaScript, Python]                 [데브옵스]
#
#                                             MainData                 시간
# 0  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:26
# 1  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:47
# 2  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:02
#         id   CompanyName           Pay   Career  \
# 0  10581.0       비바이노베이션  [4000, 6000]  [6, 15]
# 1  10651.0          페이히어  [2400, 8000]   [4, 8]
# 2  10681.0  버킷플레이스(오늘의집)  [3000, 6000]   [2, 5]
# 3  10682.0  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
#
#                                               Stacks  \
# 0                [Django, React Native, Swift, Java]
# 1                [JavaScript, React Native, ReactJS]
# 2                        [Shell, JavaScript, Python]
# 3  [GitHub Actions, CircleCI, Terraform, JavaScri...
#
#                              Job  \
# 0                    [시스템 소프트웨어]
# 1          [프론트엔드,  안드로이드,  iOS]
# 2                         [데브옵스]
# 3  [시스템/네트워크,  시스템 소프트웨어,  데브옵스]
#
#                                             MainData                 시간
# 0  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:26
# 1  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:47
# 2  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:02
# 3  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:33
#         id   CompanyName           Pay   Career  \
# 0  10581.0       비바이노베이션  [4000, 6000]  [6, 15]
# 1  10651.0          페이히어  [2400, 8000]   [4, 8]
# 2  10681.0  버킷플레이스(오늘의집)  [3000, 6000]   [2, 5]
# 3  10682.0  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
# 4  10687.0  버킷플레이스(오늘의집)  [3000, 6000]   [3, 5]
#
#                                               Stacks  \
# 0                [Django, React Native, Swift, Java]
# 1                [JavaScript, React Native, ReactJS]
# 2                        [Shell, JavaScript, Python]
# 3  [GitHub Actions, CircleCI, Terraform, JavaScri...
# 4                                                 []
#
#                              Job  \
# 0                    [시스템 소프트웨어]
# 1          [프론트엔드,  안드로이드,  iOS]
# 2                         [데브옵스]
# 3  [시스템/네트워크,  시스템 소프트웨어,  데브옵스]
# 4                         [머신러닝]
#
#                                             MainData                 시간
# 0  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:26
# 1  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:47
# 2  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:02
# 3  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:33
# 4  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:41
#         id   CompanyName           Pay   Career  \
# 0  10581.0       비바이노베이션  [4000, 6000]  [6, 15]
# 1  10651.0          페이히어  [2400, 8000]   [4, 8]
# 2  10681.0  버킷플레이스(오늘의집)  [3000, 6000]   [2, 5]
# 3  10682.0  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
# 4  10687.0  버킷플레이스(오늘의집)  [3000, 6000]   [3, 5]
# 5  10688.0  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
#
#                                               Stacks  \
# 0                [Django, React Native, Swift, Java]
# 1                [JavaScript, React Native, ReactJS]
# 2                        [Shell, JavaScript, Python]
# 3  [GitHub Actions, CircleCI, Terraform, JavaScri...
# 4                                                 []
# 5                                                 []
#
#                              Job  \
# 0                    [시스템 소프트웨어]
# 1          [프론트엔드,  안드로이드,  iOS]
# 2                         [데브옵스]
# 3  [시스템/네트워크,  시스템 소프트웨어,  데브옵스]
# 4                         [머신러닝]
# 5                         [머신러닝]
#
#                                             MainData                 시간
# 0  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:26
# 1  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:47
# 2  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:02
# 3  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:33
# 4  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:41
# 5  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:41
#         id   CompanyName           Pay   Career  \
# 0  10581.0       비바이노베이션  [4000, 6000]  [6, 15]
# 1  10651.0          페이히어  [2400, 8000]   [4, 8]
# 2  10681.0  버킷플레이스(오늘의집)  [3000, 6000]   [2, 5]
# 3  10682.0  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
# 4  10687.0  버킷플레이스(오늘의집)  [3000, 6000]   [3, 5]
# 5  10688.0  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
# 6  10689.0  버킷플레이스(오늘의집)  [3000, 6000]   [3, 5]
#
#                                               Stacks  \
# 0                [Django, React Native, Swift, Java]
# 1                [JavaScript, React Native, ReactJS]
# 2                        [Shell, JavaScript, Python]
# 3  [GitHub Actions, CircleCI, Terraform, JavaScri...
# 4                                                 []
# 5                                                 []
# 6                                                 []
#
#                              Job  \
# 0                    [시스템 소프트웨어]
# 1          [프론트엔드,  안드로이드,  iOS]
# 2                         [데브옵스]
# 3  [시스템/네트워크,  시스템 소프트웨어,  데브옵스]
# 4                         [머신러닝]
# 5                         [머신러닝]
# 6                    [데이터 엔지니어링]
#
#                                             MainData                 시간
# 0  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:26
# 1  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:47
# 2  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:02
# 3  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:33
# 4  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:41
# 5  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:41
# 6  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:29
#         id   CompanyName           Pay   Career  \
# 0  10581.0       비바이노베이션  [4000, 6000]  [6, 15]
# 1  10651.0          페이히어  [2400, 8000]   [4, 8]
# 2  10681.0  버킷플레이스(오늘의집)  [3000, 6000]   [2, 5]
# 3  10682.0  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
# 4  10687.0  버킷플레이스(오늘의집)  [3000, 6000]   [3, 5]
# 5  10688.0  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
# 6  10689.0  버킷플레이스(오늘의집)  [3000, 6000]   [3, 5]
# 7  10690.0  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
#
#                                               Stacks  \
# 0                [Django, React Native, Swift, Java]
# 1                [JavaScript, React Native, ReactJS]
# 2                        [Shell, JavaScript, Python]
# 3  [GitHub Actions, CircleCI, Terraform, JavaScri...
# 4                                                 []
# 5                                                 []
# 6                                                 []
# 7                                                 []
#
#                              Job  \
# 0                    [시스템 소프트웨어]
# 1          [프론트엔드,  안드로이드,  iOS]
# 2                         [데브옵스]
# 3  [시스템/네트워크,  시스템 소프트웨어,  데브옵스]
# 4                         [머신러닝]
# 5                         [머신러닝]
# 6                    [데이터 엔지니어링]
# 7                    [데이터 엔지니어링]
#
#                                             MainData                 시간
# 0  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:26
# 1  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:47
# 2  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:02
# 3  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:33
# 4  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:41
# 5  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:41
# 6  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:29
# 7  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:45
#         id   CompanyName           Pay   Career  \
# 0  10581.0       비바이노베이션  [4000, 6000]  [6, 15]
# 1  10651.0          페이히어  [2400, 8000]   [4, 8]
# 2  10681.0  버킷플레이스(오늘의집)  [3000, 6000]   [2, 5]
# 3  10682.0  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
# 4  10687.0  버킷플레이스(오늘의집)  [3000, 6000]   [3, 5]
# 5  10688.0  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
# 6  10689.0  버킷플레이스(오늘의집)  [3000, 6000]   [3, 5]
# 7  10690.0  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
# 8  10787.0          라인쓰리  [3600, 7000]  [1, 10]
#
#                                               Stacks  \
# 0                [Django, React Native, Swift, Java]
# 1                [JavaScript, React Native, ReactJS]
# 2                        [Shell, JavaScript, Python]
# 3  [GitHub Actions, CircleCI, Terraform, JavaScri...
# 4                                                 []
# 5                                                 []
# 6                                                 []
# 7                                                 []
# 8                      [Dart, iOS, Android, flutter]
#
#                              Job  \
# 0                    [시스템 소프트웨어]
# 1          [프론트엔드,  안드로이드,  iOS]
# 2                         [데브옵스]
# 3  [시스템/네트워크,  시스템 소프트웨어,  데브옵스]
# 4                         [머신러닝]
# 5                         [머신러닝]
# 6                    [데이터 엔지니어링]
# 7                    [데이터 엔지니어링]
# 8                  [안드로이드,  iOS]
#
#                                             MainData                 시간
# 0  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:26
# 1  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:47
# 2  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:02
# 3  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:33
# 4  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:41
# 5  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:41
# 6  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:29
# 7  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:45
# 8  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:06
#         id   CompanyName           Pay   Career  \
# 0  10581.0       비바이노베이션  [4000, 6000]  [6, 15]
# 1  10651.0          페이히어  [2400, 8000]   [4, 8]
# 2  10681.0  버킷플레이스(오늘의집)  [3000, 6000]   [2, 5]
# 3  10682.0  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
# 4  10687.0  버킷플레이스(오늘의집)  [3000, 6000]   [3, 5]
# 5  10688.0  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
# 6  10689.0  버킷플레이스(오늘의집)  [3000, 6000]   [3, 5]
# 7  10690.0  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
# 8  10787.0          라인쓰리  [3600, 7000]  [1, 10]
# 9  11158.0      씨엠아이파트너스  [2400, 8000]  [3, 10]
#
#                                               Stacks  \
# 0                [Django, React Native, Swift, Java]
# 1                [JavaScript, React Native, ReactJS]
# 2                        [Shell, JavaScript, Python]
# 3  [GitHub Actions, CircleCI, Terraform, JavaScri...
# 4                                                 []
# 5                                                 []
# 6                                                 []
# 7                                                 []
# 8                      [Dart, iOS, Android, flutter]
# 9                      [JIRA, HTML, CSS, JavaScript]
#
#                              Job  \
# 0                    [시스템 소프트웨어]
# 1          [프론트엔드,  안드로이드,  iOS]
# 2                         [데브옵스]
# 3  [시스템/네트워크,  시스템 소프트웨어,  데브옵스]
# 4                         [머신러닝]
# 5                         [머신러닝]
# 6                    [데이터 엔지니어링]
# 7                    [데이터 엔지니어링]
# 8                  [안드로이드,  iOS]
# 9                        [프론트엔드]
#
#                                             MainData                 시간
# 0  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:26
# 1  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:47
# 2  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:02
# 3  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:33
# 4  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:41
# 5  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:41
# 6  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:29
# 7  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:45
# 8  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:06
# 9  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:17
#          id   CompanyName           Pay   Career  \
# 0   10581.0       비바이노베이션  [4000, 6000]  [6, 15]
# 1   10651.0          페이히어  [2400, 8000]   [4, 8]
# 2   10681.0  버킷플레이스(오늘의집)  [3000, 6000]   [2, 5]
# 3   10682.0  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
# 4   10687.0  버킷플레이스(오늘의집)  [3000, 6000]   [3, 5]
# 5   10688.0  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
# 6   10689.0  버킷플레이스(오늘의집)  [3000, 6000]   [3, 5]
# 7   10690.0  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
# 8   10787.0          라인쓰리  [3600, 7000]  [1, 10]
# 9   11158.0      씨엠아이파트너스  [2400, 8000]  [3, 10]
# 10  11489.0          텐핑거스  [3000, 6000]  [4, 10]
#
#                                                Stacks  \
# 0                 [Django, React Native, Swift, Java]
# 1                 [JavaScript, React Native, ReactJS]
# 2                         [Shell, JavaScript, Python]
# 3   [GitHub Actions, CircleCI, Terraform, JavaScri...
# 4                                                  []
# 5                                                  []
# 6                                                  []
# 7                                                  []
# 8                       [Dart, iOS, Android, flutter]
# 9                       [JIRA, HTML, CSS, JavaScript]
# 10              [Next.js, AWS CloudFront, TypeScript]
#
#                               Job  \
# 0                     [시스템 소프트웨어]
# 1           [프론트엔드,  안드로이드,  iOS]
# 2                          [데브옵스]
# 3   [시스템/네트워크,  시스템 소프트웨어,  데브옵스]
# 4                          [머신러닝]
# 5                          [머신러닝]
# 6                     [데이터 엔지니어링]
# 7                     [데이터 엔지니어링]
# 8                   [안드로이드,  iOS]
# 9                         [프론트엔드]
# 10              [프론트엔드,  응용 프로그램]
#
#                                              MainData                 시간
# 0   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:26
# 1   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:47
# 2   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:02
# 3   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:33
# 4   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:41
# 5   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:41
# 6   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:29
# 7   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:45
# 8   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:06
# 9   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:17
# 10  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:18
#          id   CompanyName           Pay   Career  \
# 0   10581.0       비바이노베이션  [4000, 6000]  [6, 15]
# 1   10651.0          페이히어  [2400, 8000]   [4, 8]
# 2   10681.0  버킷플레이스(오늘의집)  [3000, 6000]   [2, 5]
# 3   10682.0  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
# 4   10687.0  버킷플레이스(오늘의집)  [3000, 6000]   [3, 5]
# 5   10688.0  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
# 6   10689.0  버킷플레이스(오늘의집)  [3000, 6000]   [3, 5]
# 7   10690.0  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
# 8   10787.0          라인쓰리  [3600, 7000]  [1, 10]
# 9   11158.0      씨엠아이파트너스  [2400, 8000]  [3, 10]
# 10  11489.0          텐핑거스  [3000, 6000]  [4, 10]
# 11  11607.0         아이비즈온  [4000, 8000]  [3, 10]
#
#                                                Stacks  \
# 0                 [Django, React Native, Swift, Java]
# 1                 [JavaScript, React Native, ReactJS]
# 2                         [Shell, JavaScript, Python]
# 3   [GitHub Actions, CircleCI, Terraform, JavaScri...
# 4                                                  []
# 5                                                  []
# 6                                                  []
# 7                                                  []
# 8                       [Dart, iOS, Android, flutter]
# 9                       [JIRA, HTML, CSS, JavaScript]
# 10              [Next.js, AWS CloudFront, TypeScript]
# 11  [GitHub, JavaScript, Spring, TypeScript, Java,...
#
#                               Job  \
# 0                     [시스템 소프트웨어]
# 1           [프론트엔드,  안드로이드,  iOS]
# 2                          [데브옵스]
# 3   [시스템/네트워크,  시스템 소프트웨어,  데브옵스]
# 4                          [머신러닝]
# 5                          [머신러닝]
# 6                     [데이터 엔지니어링]
# 7                     [데이터 엔지니어링]
# 8                   [안드로이드,  iOS]
# 9                         [프론트엔드]
# 10              [프론트엔드,  응용 프로그램]
# 11                        [웹 풀스택]
#
#                                              MainData                 시간
# 0   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:26
# 1   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:47
# 2   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:02
# 3   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:33
# 4   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:41
# 5   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:41
# 6   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:29
# 7   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:45
# 8   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:06
# 9   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:17
# 10  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:18
# 11  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:51
#          id   CompanyName           Pay   Career  \
# 0   10581.0       비바이노베이션  [4000, 6000]  [6, 15]
# 1   10651.0          페이히어  [2400, 8000]   [4, 8]
# 2   10681.0  버킷플레이스(오늘의집)  [3000, 6000]   [2, 5]
# 3   10682.0  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
# 4   10687.0  버킷플레이스(오늘의집)  [3000, 6000]   [3, 5]
# 5   10688.0  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
# 6   10689.0  버킷플레이스(오늘의집)  [3000, 6000]   [3, 5]
# 7   10690.0  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
# 8   10787.0          라인쓰리  [3600, 7000]  [1, 10]
# 9   11158.0      씨엠아이파트너스  [2400, 8000]  [3, 10]
# 10  11489.0          텐핑거스  [3000, 6000]  [4, 10]
# 11  11607.0         아이비즈온  [4000, 8000]  [3, 10]
# 12  11611.0         아이비즈온  [4000, 8000]  [3, 10]
#
#                                                Stacks  \
# 0                 [Django, React Native, Swift, Java]
# 1                 [JavaScript, React Native, ReactJS]
# 2                         [Shell, JavaScript, Python]
# 3   [GitHub Actions, CircleCI, Terraform, JavaScri...
# 4                                                  []
# 5                                                  []
# 6                                                  []
# 7                                                  []
# 8                       [Dart, iOS, Android, flutter]
# 9                       [JIRA, HTML, CSS, JavaScript]
# 10              [Next.js, AWS CloudFront, TypeScript]
# 11  [GitHub, JavaScript, Spring, TypeScript, Java,...
# 12  [MongoDB, ReactJS, Angular, JavaScript, TypeSc...
#
#                               Job  \
# 0                     [시스템 소프트웨어]
# 1           [프론트엔드,  안드로이드,  iOS]
# 2                          [데브옵스]
# 3   [시스템/네트워크,  시스템 소프트웨어,  데브옵스]
# 4                          [머신러닝]
# 5                          [머신러닝]
# 6                     [데이터 엔지니어링]
# 7                     [데이터 엔지니어링]
# 8                   [안드로이드,  iOS]
# 9                         [프론트엔드]
# 10              [프론트엔드,  응용 프로그램]
# 11                        [웹 풀스택]
# 12                        [프론트엔드]
#
#                                              MainData                 시간
# 0   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:26
# 1   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:47
# 2   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:02
# 3   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:33
# 4   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:41
# 5   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:41
# 6   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:29
# 7   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:45
# 8   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:06
# 9   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:17
# 10  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:18
# 11  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:51
# 12  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:19
#          id   CompanyName           Pay   Career  \
# 0   10581.0       비바이노베이션  [4000, 6000]  [6, 15]
# 1   10651.0          페이히어  [2400, 8000]   [4, 8]
# 2   10681.0  버킷플레이스(오늘의집)  [3000, 6000]   [2, 5]
# 3   10682.0  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
# 4   10687.0  버킷플레이스(오늘의집)  [3000, 6000]   [3, 5]
# 5   10688.0  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
# 6   10689.0  버킷플레이스(오늘의집)  [3000, 6000]   [3, 5]
# 7   10690.0  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
# 8   10787.0          라인쓰리  [3600, 7000]  [1, 10]
# 9   11158.0      씨엠아이파트너스  [2400, 8000]  [3, 10]
# 10  11489.0          텐핑거스  [3000, 6000]  [4, 10]
# 11  11607.0         아이비즈온  [4000, 8000]  [3, 10]
# 12  11611.0         아이비즈온  [4000, 8000]  [3, 10]
# 13  11612.0         아이비즈온  [4000, 8000]  [3, 10]
#
#                                                Stacks  \
# 0                 [Django, React Native, Swift, Java]
# 1                 [JavaScript, React Native, ReactJS]
# 2                         [Shell, JavaScript, Python]
# 3   [GitHub Actions, CircleCI, Terraform, JavaScri...
# 4                                                  []
# 5                                                  []
# 6                                                  []
# 7                                                  []
# 8                       [Dart, iOS, Android, flutter]
# 9                       [JIRA, HTML, CSS, JavaScript]
# 10              [Next.js, AWS CloudFront, TypeScript]
# 11  [GitHub, JavaScript, Spring, TypeScript, Java,...
# 12  [MongoDB, ReactJS, Angular, JavaScript, TypeSc...
# 13  [Java, Docker, Microsoft Azure, GCP(Google Clo...
#
#                               Job  \
# 0                     [시스템 소프트웨어]
# 1           [프론트엔드,  안드로이드,  iOS]
# 2                          [데브옵스]
# 3   [시스템/네트워크,  시스템 소프트웨어,  데브옵스]
# 4                          [머신러닝]
# 5                          [머신러닝]
# 6                     [데이터 엔지니어링]
# 7                     [데이터 엔지니어링]
# 8                   [안드로이드,  iOS]
# 9                         [프론트엔드]
# 10              [프론트엔드,  응용 프로그램]
# 11                        [웹 풀스택]
# 12                        [프론트엔드]
# 13                       [서버/백엔드]
#
#                                              MainData                 시간
# 0   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:26
# 1   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:47
# 2   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:02
# 3   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:33
# 4   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:41
# 5   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:41
# 6   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:29
# 7   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:45
# 8   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:06
# 9   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:17
# 10  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:18
# 11  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:51
# 12  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:19
# 13  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:44
#          id   CompanyName            Pay   Career  \
# 0   10581.0       비바이노베이션   [4000, 6000]  [6, 15]
# 1   10651.0          페이히어   [2400, 8000]   [4, 8]
# 2   10681.0  버킷플레이스(오늘의집)   [3000, 6000]   [2, 5]
# 3   10682.0  버킷플레이스(오늘의집)   [3000, 6000]  [6, 20]
# 4   10687.0  버킷플레이스(오늘의집)   [3000, 6000]   [3, 5]
# 5   10688.0  버킷플레이스(오늘의집)   [3000, 6000]  [6, 20]
# 6   10689.0  버킷플레이스(오늘의집)   [3000, 6000]   [3, 5]
# 7   10690.0  버킷플레이스(오늘의집)   [3000, 6000]  [6, 20]
# 8   10787.0          라인쓰리   [3600, 7000]  [1, 10]
# 9   11158.0      씨엠아이파트너스   [2400, 8000]  [3, 10]
# 10  11489.0          텐핑거스   [3000, 6000]  [4, 10]
# 11  11607.0         아이비즈온   [4000, 8000]  [3, 10]
# 12  11611.0         아이비즈온   [4000, 8000]  [3, 10]
# 13  11612.0         아이비즈온   [4000, 8000]  [3, 10]
# 14  11683.0          클래스유  [4000, 10000]    경력 무관
#
#                                                Stacks  \
# 0                 [Django, React Native, Swift, Java]
# 1                 [JavaScript, React Native, ReactJS]
# 2                         [Shell, JavaScript, Python]
# 3   [GitHub Actions, CircleCI, Terraform, JavaScri...
# 4                                                  []
# 5                                                  []
# 6                                                  []
# 7                                                  []
# 8                       [Dart, iOS, Android, flutter]
# 9                       [JIRA, HTML, CSS, JavaScript]
# 10              [Next.js, AWS CloudFront, TypeScript]
# 11  [GitHub, JavaScript, Spring, TypeScript, Java,...
# 12  [MongoDB, ReactJS, Angular, JavaScript, TypeSc...
# 13  [Java, Docker, Microsoft Azure, GCP(Google Clo...
# 14  [Kotlin, Java, CI/CD, Docker, NoSQL, PHP, Lara...
#
#                               Job  \
# 0                     [시스템 소프트웨어]
# 1           [프론트엔드,  안드로이드,  iOS]
# 2                          [데브옵스]
# 3   [시스템/네트워크,  시스템 소프트웨어,  데브옵스]
# 4                          [머신러닝]
# 5                          [머신러닝]
# 6                     [데이터 엔지니어링]
# 7                     [데이터 엔지니어링]
# 8                   [안드로이드,  iOS]
# 9                         [프론트엔드]
# 10              [프론트엔드,  응용 프로그램]
# 11                        [웹 풀스택]
# 12                        [프론트엔드]
# 13                       [서버/백엔드]
# 14                [서버/백엔드,  데브옵스]
#
#                                              MainData                 시간
# 0   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:26
# 1   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:47
# 2   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:02
# 3   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:33
# 4   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:41
# 5   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:41
# 6   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:29
# 7   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:45
# 8   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:06
# 9   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:17
# 10  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:18
# 11  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:51
# 12  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:19
# 13  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:44
# 14  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:42
#          id   CompanyName            Pay   Career  \
# 0   10581.0       비바이노베이션   [4000, 6000]  [6, 15]
# 1   10651.0          페이히어   [2400, 8000]   [4, 8]
# 2   10681.0  버킷플레이스(오늘의집)   [3000, 6000]   [2, 5]
# 3   10682.0  버킷플레이스(오늘의집)   [3000, 6000]  [6, 20]
# 4   10687.0  버킷플레이스(오늘의집)   [3000, 6000]   [3, 5]
# 5   10688.0  버킷플레이스(오늘의집)   [3000, 6000]  [6, 20]
# 6   10689.0  버킷플레이스(오늘의집)   [3000, 6000]   [3, 5]
# 7   10690.0  버킷플레이스(오늘의집)   [3000, 6000]  [6, 20]
# 8   10787.0          라인쓰리   [3600, 7000]  [1, 10]
# 9   11158.0      씨엠아이파트너스   [2400, 8000]  [3, 10]
# 10  11489.0          텐핑거스   [3000, 6000]  [4, 10]
# 11  11607.0         아이비즈온   [4000, 8000]  [3, 10]
# 12  11611.0         아이비즈온   [4000, 8000]  [3, 10]
# 13  11612.0         아이비즈온   [4000, 8000]  [3, 10]
# 14  11683.0          클래스유  [4000, 10000]    경력 무관
# 15  11684.0          클래스유  [4000, 10000]   [2, 8]
#
#                                                Stacks  \
# 0                 [Django, React Native, Swift, Java]
# 1                 [JavaScript, React Native, ReactJS]
# 2                         [Shell, JavaScript, Python]
# 3   [GitHub Actions, CircleCI, Terraform, JavaScri...
# 4                                                  []
# 5                                                  []
# 6                                                  []
# 7                                                  []
# 8                       [Dart, iOS, Android, flutter]
# 9                       [JIRA, HTML, CSS, JavaScript]
# 10              [Next.js, AWS CloudFront, TypeScript]
# 11  [GitHub, JavaScript, Spring, TypeScript, Java,...
# 12  [MongoDB, ReactJS, Angular, JavaScript, TypeSc...
# 13  [Java, Docker, Microsoft Azure, GCP(Google Clo...
# 14  [Kotlin, Java, CI/CD, Docker, NoSQL, PHP, Lara...
# 15  [Node.js, SEO, GitHub, Git, REST API, ReactJS,...
#
#                               Job  \
# 0                     [시스템 소프트웨어]
# 1           [프론트엔드,  안드로이드,  iOS]
# 2                          [데브옵스]
# 3   [시스템/네트워크,  시스템 소프트웨어,  데브옵스]
# 4                          [머신러닝]
# 5                          [머신러닝]
# 6                     [데이터 엔지니어링]
# 7                     [데이터 엔지니어링]
# 8                   [안드로이드,  iOS]
# 9                         [프론트엔드]
# 10              [프론트엔드,  응용 프로그램]
# 11                        [웹 풀스택]
# 12                        [프론트엔드]
# 13                       [서버/백엔드]
# 14                [서버/백엔드,  데브옵스]
# 15                        [프론트엔드]
#
#                                              MainData                 시간
# 0   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:26
# 1   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:47
# 2   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:02
# 3   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:33
# 4   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:41
# 5   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:41
# 6   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:29
# 7   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:45
# 8   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:06
# 9   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:17
# 10  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:18
# 11  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:51
# 12  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:19
# 13  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:44
# 14  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:42
# 15  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:46
#          id   CompanyName            Pay   Career  \
# 0   10581.0       비바이노베이션   [4000, 6000]  [6, 15]
# 1   10651.0          페이히어   [2400, 8000]   [4, 8]
# 2   10681.0  버킷플레이스(오늘의집)   [3000, 6000]   [2, 5]
# 3   10682.0  버킷플레이스(오늘의집)   [3000, 6000]  [6, 20]
# 4   10687.0  버킷플레이스(오늘의집)   [3000, 6000]   [3, 5]
# 5   10688.0  버킷플레이스(오늘의집)   [3000, 6000]  [6, 20]
# 6   10689.0  버킷플레이스(오늘의집)   [3000, 6000]   [3, 5]
# 7   10690.0  버킷플레이스(오늘의집)   [3000, 6000]  [6, 20]
# 8   10787.0          라인쓰리   [3600, 7000]  [1, 10]
# 9   11158.0      씨엠아이파트너스   [2400, 8000]  [3, 10]
# 10  11489.0          텐핑거스   [3000, 6000]  [4, 10]
# 11  11607.0         아이비즈온   [4000, 8000]  [3, 10]
# 12  11611.0         아이비즈온   [4000, 8000]  [3, 10]
# 13  11612.0         아이비즈온   [4000, 8000]  [3, 10]
# 14  11683.0          클래스유  [4000, 10000]    경력 무관
# 15  11684.0          클래스유  [4000, 10000]   [2, 8]
# 16  11687.0  버킷플레이스(오늘의집)   [4000, 6000]    경력 무관
#
#                                                Stacks  \
# 0                 [Django, React Native, Swift, Java]
# 1                 [JavaScript, React Native, ReactJS]
# 2                         [Shell, JavaScript, Python]
# 3   [GitHub Actions, CircleCI, Terraform, JavaScri...
# 4                                                  []
# 5                                                  []
# 6                                                  []
# 7                                                  []
# 8                       [Dart, iOS, Android, flutter]
# 9                       [JIRA, HTML, CSS, JavaScript]
# 10              [Next.js, AWS CloudFront, TypeScript]
# 11  [GitHub, JavaScript, Spring, TypeScript, Java,...
# 12  [MongoDB, ReactJS, Angular, JavaScript, TypeSc...
# 13  [Java, Docker, Microsoft Azure, GCP(Google Clo...
# 14  [Kotlin, Java, CI/CD, Docker, NoSQL, PHP, Lara...
# 15  [Node.js, SEO, GitHub, Git, REST API, ReactJS,...
# 16                                                 []
#
#                               Job  \
# 0                     [시스템 소프트웨어]
# 1           [프론트엔드,  안드로이드,  iOS]
# 2                          [데브옵스]
# 3   [시스템/네트워크,  시스템 소프트웨어,  데브옵스]
# 4                          [머신러닝]
# 5                          [머신러닝]
# 6                     [데이터 엔지니어링]
# 7                     [데이터 엔지니어링]
# 8                   [안드로이드,  iOS]
# 9                         [프론트엔드]
# 10              [프론트엔드,  응용 프로그램]
# 11                        [웹 풀스택]
# 12                        [프론트엔드]
# 13                       [서버/백엔드]
# 14                [서버/백엔드,  데브옵스]
# 15                        [프론트엔드]
# 16                          [iOS]
#
#                                              MainData                 시간
# 0   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:26
# 1   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:47
# 2   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:02
# 3   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:33
# 4   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:41
# 5   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:41
# 6   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:29
# 7   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:45
# 8   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:06
# 9   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:17
# 10  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:18
# 11  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:51
# 12  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:19
# 13  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:44
# 14  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:42
# 15  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:46
# 16  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:41
#          id   CompanyName            Pay   Career  \
# 0   10581.0       비바이노베이션   [4000, 6000]  [6, 15]
# 1   10651.0          페이히어   [2400, 8000]   [4, 8]
# 2   10681.0  버킷플레이스(오늘의집)   [3000, 6000]   [2, 5]
# 3   10682.0  버킷플레이스(오늘의집)   [3000, 6000]  [6, 20]
# 4   10687.0  버킷플레이스(오늘의집)   [3000, 6000]   [3, 5]
# 5   10688.0  버킷플레이스(오늘의집)   [3000, 6000]  [6, 20]
# 6   10689.0  버킷플레이스(오늘의집)   [3000, 6000]   [3, 5]
# 7   10690.0  버킷플레이스(오늘의집)   [3000, 6000]  [6, 20]
# 8   10787.0          라인쓰리   [3600, 7000]  [1, 10]
# 9   11158.0      씨엠아이파트너스   [2400, 8000]  [3, 10]
# 10  11489.0          텐핑거스   [3000, 6000]  [4, 10]
# 11  11607.0         아이비즈온   [4000, 8000]  [3, 10]
# 12  11611.0         아이비즈온   [4000, 8000]  [3, 10]
# 13  11612.0         아이비즈온   [4000, 8000]  [3, 10]
# 14  11683.0          클래스유  [4000, 10000]    경력 무관
# 15  11684.0          클래스유  [4000, 10000]   [2, 8]
# 16  11687.0  버킷플레이스(오늘의집)   [4000, 6000]    경력 무관
# 17  11692.0  버킷플레이스(오늘의집)   [4000, 6000]    경력 무관
#
#                                                Stacks  \
# 0                 [Django, React Native, Swift, Java]
# 1                 [JavaScript, React Native, ReactJS]
# 2                         [Shell, JavaScript, Python]
# 3   [GitHub Actions, CircleCI, Terraform, JavaScri...
# 4                                                  []
# 5                                                  []
# 6                                                  []
# 7                                                  []
# 8                       [Dart, iOS, Android, flutter]
# 9                       [JIRA, HTML, CSS, JavaScript]
# 10              [Next.js, AWS CloudFront, TypeScript]
# 11  [GitHub, JavaScript, Spring, TypeScript, Java,...
# 12  [MongoDB, ReactJS, Angular, JavaScript, TypeSc...
# 13  [Java, Docker, Microsoft Azure, GCP(Google Clo...
# 14  [Kotlin, Java, CI/CD, Docker, NoSQL, PHP, Lara...
# 15  [Node.js, SEO, GitHub, Git, REST API, ReactJS,...
# 16                                                 []
# 17                                                 []
#
#                               Job  \
# 0                     [시스템 소프트웨어]
# 1           [프론트엔드,  안드로이드,  iOS]
# 2                          [데브옵스]
# 3   [시스템/네트워크,  시스템 소프트웨어,  데브옵스]
# 4                          [머신러닝]
# 5                          [머신러닝]
# 6                     [데이터 엔지니어링]
# 7                     [데이터 엔지니어링]
# 8                   [안드로이드,  iOS]
# 9                         [프론트엔드]
# 10              [프론트엔드,  응용 프로그램]
# 11                        [웹 풀스택]
# 12                        [프론트엔드]
# 13                       [서버/백엔드]
# 14                [서버/백엔드,  데브옵스]
# 15                        [프론트엔드]
# 16                          [iOS]
# 17                        [안드로이드]
#
#                                              MainData                 시간
# 0   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:26
# 1   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:47
# 2   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:02
# 3   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:33
# 4   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:41
# 5   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:41
# 6   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:29
# 7   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:45
# 8   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:06
# 9   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:17
# 10  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:18
# 11  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:51
# 12  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:19
# 13  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:44
# 14  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:42
# 15  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:46
# 16  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:41
# 17  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:21
#          id   CompanyName            Pay   Career  \
# 0   10581.0       비바이노베이션   [4000, 6000]  [6, 15]
# 1   10651.0          페이히어   [2400, 8000]   [4, 8]
# 2   10681.0  버킷플레이스(오늘의집)   [3000, 6000]   [2, 5]
# 3   10682.0  버킷플레이스(오늘의집)   [3000, 6000]  [6, 20]
# 4   10687.0  버킷플레이스(오늘의집)   [3000, 6000]   [3, 5]
# 5   10688.0  버킷플레이스(오늘의집)   [3000, 6000]  [6, 20]
# 6   10689.0  버킷플레이스(오늘의집)   [3000, 6000]   [3, 5]
# 7   10690.0  버킷플레이스(오늘의집)   [3000, 6000]  [6, 20]
# 8   10787.0          라인쓰리   [3600, 7000]  [1, 10]
# 9   11158.0      씨엠아이파트너스   [2400, 8000]  [3, 10]
# 10  11489.0          텐핑거스   [3000, 6000]  [4, 10]
# 11  11607.0         아이비즈온   [4000, 8000]  [3, 10]
# 12  11611.0         아이비즈온   [4000, 8000]  [3, 10]
# 13  11612.0         아이비즈온   [4000, 8000]  [3, 10]
# 14  11683.0          클래스유  [4000, 10000]    경력 무관
# 15  11684.0          클래스유  [4000, 10000]   [2, 8]
# 16  11687.0  버킷플레이스(오늘의집)   [4000, 6000]    경력 무관
# 17  11692.0  버킷플레이스(오늘의집)   [4000, 6000]    경력 무관
# 18  11695.0  버킷플레이스(오늘의집)   [4000, 6000]    경력 무관
#
#                                                Stacks  \
# 0                 [Django, React Native, Swift, Java]
# 1                 [JavaScript, React Native, ReactJS]
# 2                         [Shell, JavaScript, Python]
# 3   [GitHub Actions, CircleCI, Terraform, JavaScri...
# 4                                                  []
# 5                                                  []
# 6                                                  []
# 7                                                  []
# 8                       [Dart, iOS, Android, flutter]
# 9                       [JIRA, HTML, CSS, JavaScript]
# 10              [Next.js, AWS CloudFront, TypeScript]
# 11  [GitHub, JavaScript, Spring, TypeScript, Java,...
# 12  [MongoDB, ReactJS, Angular, JavaScript, TypeSc...
# 13  [Java, Docker, Microsoft Azure, GCP(Google Clo...
# 14  [Kotlin, Java, CI/CD, Docker, NoSQL, PHP, Lara...
# 15  [Node.js, SEO, GitHub, Git, REST API, ReactJS,...
# 16                                                 []
# 17                                                 []
# 18                                                 []
#
#                               Job  \
# 0                     [시스템 소프트웨어]
# 1           [프론트엔드,  안드로이드,  iOS]
# 2                          [데브옵스]
# 3   [시스템/네트워크,  시스템 소프트웨어,  데브옵스]
# 4                          [머신러닝]
# 5                          [머신러닝]
# 6                     [데이터 엔지니어링]
# 7                     [데이터 엔지니어링]
# 8                   [안드로이드,  iOS]
# 9                         [프론트엔드]
# 10              [프론트엔드,  응용 프로그램]
# 11                        [웹 풀스택]
# 12                        [프론트엔드]
# 13                       [서버/백엔드]
# 14                [서버/백엔드,  데브옵스]
# 15                        [프론트엔드]
# 16                          [iOS]
# 17                        [안드로이드]
# 18                        [프론트엔드]
#
#                                              MainData                 시간
# 0   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:26
# 1   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:47
# 2   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:02
# 3   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:33
# 4   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:41
# 5   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:41
# 6   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:29
# 7   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:45
# 8   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:06
# 9   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:17
# 10  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:18
# 11  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:51
# 12  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:19
# 13  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:44
# 14  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:42
# 15  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:46
# 16  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:41
# 17  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:21
# 18  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:46
#          id   CompanyName            Pay   Career  \
# 0   10581.0       비바이노베이션   [4000, 6000]  [6, 15]
# 1   10651.0          페이히어   [2400, 8000]   [4, 8]
# 2   10681.0  버킷플레이스(오늘의집)   [3000, 6000]   [2, 5]
# 3   10682.0  버킷플레이스(오늘의집)   [3000, 6000]  [6, 20]
# 4   10687.0  버킷플레이스(오늘의집)   [3000, 6000]   [3, 5]
# 5   10688.0  버킷플레이스(오늘의집)   [3000, 6000]  [6, 20]
# 6   10689.0  버킷플레이스(오늘의집)   [3000, 6000]   [3, 5]
# 7   10690.0  버킷플레이스(오늘의집)   [3000, 6000]  [6, 20]
# 8   10787.0          라인쓰리   [3600, 7000]  [1, 10]
# 9   11158.0      씨엠아이파트너스   [2400, 8000]  [3, 10]
# 10  11489.0          텐핑거스   [3000, 6000]  [4, 10]
# 11  11607.0         아이비즈온   [4000, 8000]  [3, 10]
# 12  11611.0         아이비즈온   [4000, 8000]  [3, 10]
# 13  11612.0         아이비즈온   [4000, 8000]  [3, 10]
# 14  11683.0          클래스유  [4000, 10000]    경력 무관
# 15  11684.0          클래스유  [4000, 10000]   [2, 8]
# 16  11687.0  버킷플레이스(오늘의집)   [4000, 6000]    경력 무관
# 17  11692.0  버킷플레이스(오늘의집)   [4000, 6000]    경력 무관
# 18  11695.0  버킷플레이스(오늘의집)   [4000, 6000]    경력 무관
# 19  11696.0  버킷플레이스(오늘의집)   [4000, 6000]    경력 무관
#
#                                                Stacks  \
# 0                 [Django, React Native, Swift, Java]
# 1                 [JavaScript, React Native, ReactJS]
# 2                         [Shell, JavaScript, Python]
# 3   [GitHub Actions, CircleCI, Terraform, JavaScri...
# 4                                                  []
# 5                                                  []
# 6                                                  []
# 7                                                  []
# 8                       [Dart, iOS, Android, flutter]
# 9                       [JIRA, HTML, CSS, JavaScript]
# 10              [Next.js, AWS CloudFront, TypeScript]
# 11  [GitHub, JavaScript, Spring, TypeScript, Java,...
# 12  [MongoDB, ReactJS, Angular, JavaScript, TypeSc...
# 13  [Java, Docker, Microsoft Azure, GCP(Google Clo...
# 14  [Kotlin, Java, CI/CD, Docker, NoSQL, PHP, Lara...
# 15  [Node.js, SEO, GitHub, Git, REST API, ReactJS,...
# 16                                                 []
# 17                                                 []
# 18                                                 []
# 19                                                 []
#
#                               Job  \
# 0                     [시스템 소프트웨어]
# 1           [프론트엔드,  안드로이드,  iOS]
# 2                          [데브옵스]
# 3   [시스템/네트워크,  시스템 소프트웨어,  데브옵스]
# 4                          [머신러닝]
# 5                          [머신러닝]
# 6                     [데이터 엔지니어링]
# 7                     [데이터 엔지니어링]
# 8                   [안드로이드,  iOS]
# 9                         [프론트엔드]
# 10              [프론트엔드,  응용 프로그램]
# 11                        [웹 풀스택]
# 12                        [프론트엔드]
# 13                       [서버/백엔드]
# 14                [서버/백엔드,  데브옵스]
# 15                        [프론트엔드]
# 16                          [iOS]
# 17                        [안드로이드]
# 18                        [프론트엔드]
# 19                       [서버/백엔드]
#
#                                              MainData                 시간
# 0   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:26
# 1   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:47
# 2   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:02
# 3   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:33
# 4   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:41
# 5   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:41
# 6   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:29
# 7   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:45
# 8   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:06
# 9   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:17
# 10  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:18
# 11  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:51
# 12  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:19
# 13  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:44
# 14  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:42
# 15  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:46
# 16  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:41
# 17  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:21
# 18  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:46
# 19  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:39
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/b5/jx16xxp14z92_scmr6jgz3br0000gn/T/ipykernel_25246/2637129436.py in <module>
#       2
#       3 for obj in bucket.objects.all():
# ----> 4     json_string = obj.get()['Body'].read().decode('utf-8')
#       5     json_dict = json.loads(json_string)
#       6     df = df.append(json_dict, ignore_index=True)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/boto3/resources/factory.py in do_action(self, *args, **kwargs)
#     578             # instance via ``self``.
#     579             def do_action(self, *args, **kwargs):
# --> 580                 response = action(self, *args, **kwargs)
#     581
#     582                 if hasattr(self, 'load'):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/boto3/resources/action.py in __call__(self, parent, *args, **kwargs)
#      86         )
#      87
# ---> 88         response = getattr(parent.meta.client, operation_name)(*args, **params)
#      89
#      90         logger.debug('Response: %r', response)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     512                 )
#     513             # The "self" in this scope is referring to the BaseClient.
# --> 514             return self._make_api_call(operation_name, kwargs)
#     515
#     516         _api_call.__name__ = str(py_operation_name)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     915         else:
#     916             apply_request_checksum(request_dict)
# --> 917             http, parsed_response = self._make_request(
#     918                 operation_model, request_dict, request_context
#     919             )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/botocore/client.py in _make_request(self, operation_model, request_dict, request_context)
#     938     def _make_request(self, operation_model, request_dict, request_context):
#     939         try:
# --> 940             return self._endpoint.make_request(operation_model, request_dict)
#     941         except Exception as e:
#     942             self.meta.events.emit(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/botocore/endpoint.py in make_request(self, operation_model, request_dict)
#     117             request_dict,
#     118         )
# --> 119         return self._send_request(request_dict, operation_model)
#     120
#     121     def create_request(self, params, operation_model=None):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/botocore/endpoint.py in _send_request(self, request_dict, operation_model)
#     197         self._update_retries_context(context, attempts)
#     198         request = self.create_request(request_dict, operation_model)
# --> 199         success_response, exception = self._get_response(
#     200             request, operation_model, context
#     201         )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/botocore/endpoint.py in _get_response(self, request, operation_model, context)
#     239         # If an exception occurs then the success_response is None.
#     240         # If no exception occurs then exception is None.
# --> 241         success_response, exception = self._do_get_response(
#     242             request, operation_model, context
#     243         )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/botocore/endpoint.py in _do_get_response(self, request, operation_model, context)
#     279             http_response = first_non_none_response(responses)
#     280             if http_response is None:
# --> 281                 http_response = self._send(request)
#     282         except HTTPClientError as e:
#     283             return (None, e)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/botocore/endpoint.py in _send(self, request)
#     375
#     376     def _send(self, request):
# --> 377         return self.http_session.send(request)
#     378
#     379
#
# ~/opt/anaconda3/lib/python3.9/site-packages/botocore/httpsession.py in send(self, request)
#     446
#     447             request_target = self._get_request_target(request.url, proxy_url)
# --> 448             urllib_response = conn.urlopen(
#     449                 method=request.method,
#     450                 url=request_target,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in getresponse(self)
#    1369         try:
#    1370             try:
# -> 1371                 response.begin()
#    1372             except ConnectionError:
#    1373                 self.close()
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# ~/opt/anaconda3/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df
# Out:
#          id   CompanyName            Pay   Career  \
# 0   10581.0       비바이노베이션   [4000, 6000]  [6, 15]
# 1   10651.0          페이히어   [2400, 8000]   [4, 8]
# 2   10681.0  버킷플레이스(오늘의집)   [3000, 6000]   [2, 5]
# 3   10682.0  버킷플레이스(오늘의집)   [3000, 6000]  [6, 20]
# 4   10687.0  버킷플레이스(오늘의집)   [3000, 6000]   [3, 5]
# 5   10688.0  버킷플레이스(오늘의집)   [3000, 6000]  [6, 20]
# 6   10689.0  버킷플레이스(오늘의집)   [3000, 6000]   [3, 5]
# 7   10690.0  버킷플레이스(오늘의집)   [3000, 6000]  [6, 20]
# 8   10787.0          라인쓰리   [3600, 7000]  [1, 10]
# 9   11158.0      씨엠아이파트너스   [2400, 8000]  [3, 10]
# 10  11489.0          텐핑거스   [3000, 6000]  [4, 10]
# 11  11607.0         아이비즈온   [4000, 8000]  [3, 10]
# 12  11611.0         아이비즈온   [4000, 8000]  [3, 10]
# 13  11612.0         아이비즈온   [4000, 8000]  [3, 10]
# 14  11683.0          클래스유  [4000, 10000]    경력 무관
# 15  11684.0          클래스유  [4000, 10000]   [2, 8]
# 16  11687.0  버킷플레이스(오늘의집)   [4000, 6000]    경력 무관
# 17  11692.0  버킷플레이스(오늘의집)   [4000, 6000]    경력 무관
# 18  11695.0  버킷플레이스(오늘의집)   [4000, 6000]    경력 무관
# 19  11696.0  버킷플레이스(오늘의집)   [4000, 6000]    경력 무관
#
#                                                Stacks  \
# 0                 [Django, React Native, Swift, Java]
# 1                 [JavaScript, React Native, ReactJS]
# 2                         [Shell, JavaScript, Python]
# 3   [GitHub Actions, CircleCI, Terraform, JavaScri...
# 4                                                  []
# 5                                                  []
# 6                                                  []
# 7                                                  []
# 8                       [Dart, iOS, Android, flutter]
# 9                       [JIRA, HTML, CSS, JavaScript]
# 10              [Next.js, AWS CloudFront, TypeScript]
# 11  [GitHub, JavaScript, Spring, TypeScript, Java,...
# 12  [MongoDB, ReactJS, Angular, JavaScript, TypeSc...
# 13  [Java, Docker, Microsoft Azure, GCP(Google Clo...
# 14  [Kotlin, Java, CI/CD, Docker, NoSQL, PHP, Lara...
# 15  [Node.js, SEO, GitHub, Git, REST API, ReactJS,...
# 16                                                 []
# 17                                                 []
# 18                                                 []
# 19                                                 []
#
#                               Job  \
# 0                     [시스템 소프트웨어]
# 1           [프론트엔드,  안드로이드,  iOS]
# 2                          [데브옵스]
# 3   [시스템/네트워크,  시스템 소프트웨어,  데브옵스]
# 4                          [머신러닝]
# 5                          [머신러닝]
# 6                     [데이터 엔지니어링]
# 7                     [데이터 엔지니어링]
# 8                   [안드로이드,  iOS]
# 9                         [프론트엔드]
# 10              [프론트엔드,  응용 프로그램]
# 11                        [웹 풀스택]
# 12                        [프론트엔드]
# 13                       [서버/백엔드]
# 14                [서버/백엔드,  데브옵스]
# 15                        [프론트엔드]
# 16                          [iOS]
# 17                        [안드로이드]
# 18                        [프론트엔드]
# 19                       [서버/백엔드]
#
#                                              MainData                 시간
# 0   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:26
# 1   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:47
# 2   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:02
# 3   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:33
# 4   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:41
# 5   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:41
# 6   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:29
# 7   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:45
# 8   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:06
# 9   <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:17
# 10  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:18
# 11  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:51
# 12  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:19
# 13  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:44
# 14  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:42
# 15  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:46
# 16  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:43:41
# 17  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:21
# 18  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:46
# 19  <div class="yO7TZRtCO7sznD0Csuw_"><section><h5...  23-03-03 15:44:39

# %%
df['id'] = df['id'].astype('int')

# %%
df
# Out:
#       id   CompanyName           Pay   Career  \
# 0  10581       비바이노베이션  [4000, 6000]  [6, 15]
# 1  10651          페이히어  [2400, 8000]   [4, 8]
# 2  10681  버킷플레이스(오늘의집)  [3000, 6000]   [2, 5]
# 3  10682  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
# 4  10687  버킷플레이스(오늘의집)  [3000, 6000]   [3, 5]
# 5  10688  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
# 6  10689  버킷플레이스(오늘의집)  [3000, 6000]   [3, 5]
# 7  10690  버킷플레이스(오늘의집)  [3000, 6000]  [6, 20]
# 8  10787          라인쓰리  [3600, 7000]  [1, 10]
#
#                                               Stacks  \
# 0                [Django, React Native, Swift, Java]
# 1                [JavaScript, React Native, ReactJS]
# 2                        [Shell, JavaScript, Python]
# 3  [GitHub Actions, CircleCI, Terraform, JavaScri...
# 4                                                 []
# 5                                                 []
# 6                                                 []
# 7                                                 []
# 8                      [Dart, iOS, Android, flutter]
#
#                              Job                 시간
# 0                    [시스템 소프트웨어]  23-02-27 19:38:17
# 1          [프론트엔드,  안드로이드,  iOS]  23-02-27 19:38:38
# 2                         [데브옵스]  23-02-27 19:37:53
# 3  [시스템/네트워크,  시스템 소프트웨어,  데브옵스]  23-02-27 19:38:25
# 4                         [머신러닝]  23-02-27 19:37:29
# 5                         [머신러닝]  23-02-27 19:38:32
# 6                    [데이터 엔지니어링]  23-02-27 19:38:20
# 7                    [데이터 엔지니어링]  23-02-27 19:38:36
# 8                  [안드로이드,  iOS]  23-02-27 19:37:57
